# %%
import numpy as np

# %%
def softmax(x) :
  e_x = np.exp(x - x.max())
  return e_x / e_x.sum()

# %%
x = np.array([1.0, 1.0, 2.0, 3.0, 4.0])
x
# Out:
# array([1., 1., 2., 3., 4.])

# %%
y = softmax(x)
print(y)
print(y.sum())
# Out:
# [0.03106277 0.03106277 0.08443737 0.22952458 0.6239125 ]
# 1.0
